# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **EBUKA NWAFORNSO** <br>
# Data Professional

# %% [markdown]
# *I am interested Data Science to create amazing prediction models to help businesses make better data driven decisions. <br>
# As my skills sharpen, I'd love to build amazing models for Mechanical engineering problems.*

# %% [markdown]
# ### The code in the next cell outputs the product of 200 and 5.

# %%
print(200*5)
# Out:
# 1000

# %% [markdown]
# ### 2 countries in Africa and their capital;
# 1. **Nigeria**
#     - Abuja
# 2. **Ghana**
#     - Accra
#
# ***
#
# ### Types of chocolate;
# - Milk chocolate
# - Dark chocolate
# - White chocolate
#
#
# ![jessica-loaiza-DHYfjAe_eeo-unsplash (1).jpg](attachment:dfa531bb-23ad-49dd-bb29-ea4ab59b89b2.jpg)
